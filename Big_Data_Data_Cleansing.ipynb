# %%
#Libraries or Extensions
#=======================
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import math

#Data Source
#=======================
heart_data = pd.read_csv('C:\\Users\\allwy\\OneDrive\\Desktop\\Big_Data_Project_Report\\heart.csv')
heart_data.head(12)
print(str(len(heart_data.index)))

#Sex of Respondents
#==================
import matplotlib.pyplot
import seaborn as sns
import pandas as pd

heart_data = pd.read_csv('C:\\Users\\allwy\\OneDrive\\Desktop\\Big_Data_Project_Report\\heart.csv')
heart_data.head(12)
print(str(len(heart_data.index)))
sns.countplot(x="Sex", data=heart_data)
matplotlib.pyplot.show()

#Age of Respondents
#==================
import matplotlib.pyplot
import seaborn as sns
import pandas as pd

heart_data = pd.read_csv( 'C:\\Users\\allwy\\OneDrive\\Desktop\\Big_Data_Project_Report\\heart.csv' )
heart_data.head(12)
print(str(len(heart_data.index)))
sns.countplot(x="Age", data=heart_data)
matplotlib.pyplot.show()

#To check for any Blank values
#=============================
import pandas as pd

# to display the entire output in Pycharm Screen
pd.set_option ( 'display.width' , 500 )
pd.set_option ( 'display.max_columns' , 12 )
pd.set_option ( 'display.max_rows' , 1000 )

heart_data = pd.read_csv ( 'C:\\Users\\allwy\\OneDrive\\Desktop\\Big_Data_Project_Report\\heart.csv' )
heart_data.head ( 12 )

data2 = heart_data.isnull ( )
print ( data2 )

data3 = heart_data.isnull().sum()
print ( data3 )

#Heat Map Plot to identify blank values in the Dataset
#=====================================================
import matplotlib.pyplot
import pandas as pd
import seaborn as sns

heart_data = pd.read_csv ( 'C:\\Users\\allwy\\OneDrive\\Desktop\\Big_Data_Project_Report\\heart.csv' )
heart_data.head ( 12 )
sns.heatmap ( heart_data.isnull ( ) , yticklabels=False , cmap="Blues_r" )
matplotlib.pyplot.show ( )

#=====================================================
#No Need to drop or replace values since there is no requirement to clean the dataset
#=====================================================

#Age Vs Sex & Density
#====================

import matplotlib.pyplot
import pandas as pd
import seaborn as sns

heart_data = pd.read_csv( 'C:\\Users\\allwy\\OneDrive\\Desktop\\Big_Data_Project_Report\\heart.csv' )
heart_data.head(12)
print(str(len(heart_data.index)))
sns.displot(
  data=heart_data,
  x="Age",
  col="ChestPainType",
  hue="Sex",
  kind="kde",
  common_norm=False,
  aspect=1
)

matplotlib.pyplot.show()


#Age, Sex Vs Cholesterol
#====================

import matplotlib.pyplot
import pandas as pd
import seaborn as sns

heart_data = pd.read_csv( 'C:\\Users\\allwy\\OneDrive\\Desktop\\Big_Data_Project_Report\\heart.csv' )
heart_data.head(12)
print(str(len(heart_data.index)))
sns.scatterplot(data=heart_data, x="Age", y="Cholesterol", hue="Sex")
sns.rugplot(data=heart_data, x="Age", y="Cholesterol", hue="Sex")

matplotlib.pyplot.show()


#Age, Sex Vs RestingBP
#====================

#Age, Sex Vs Cholesterol
#====================

import matplotlib.pyplot
import pandas as pd
import seaborn as sns

heart_data = pd.read_csv( 'C:\\Users\\allwy\\OneDrive\\Desktop\\Big_Data_Project_Report\\heart.csv' )
heart_data.head(12)
print(str(len(heart_data.index)))
sns.scatterplot(data=heart_data, x="Age", y="RestingBP", hue="Sex")
sns.rugplot(data=heart_data, x="Age", y="RestingBP", hue="Sex")

matplotlib.pyplot.show()
# Out:
# 918
# 918
# 918
#        Age    Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  MaxHR  ExerciseAngina  Oldpeak  ST_Slope  HeartDisease
# 0    False  False          False      False        False      False       False  False           False    False     False         False
# 1    False  False          False      False        False      False       False  False           False    False     False         False
# 2    False  False          False      False        False      False       False  False           False    False     False         False
# 3    False  False          False      False        False      False       False  False           False    False     False         False
# 4    False  False          False      False        False      False       False  False           False    False     False         False
# 5    False  False          False      False        False      False       False  False           False    False     False         False
# ...

# %%
#
